# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student_score_data.csv")
df
# Out:
#      study_hours  sleep_hours  attendance  marks
# 0           5.25         7.79        77.1   78.9
# 1           4.29         6.09        83.9   76.6
# 2           5.47         8.40        90.0   81.6
# 3           6.78         5.60        93.7   87.3
# 4           4.15         7.59        73.0   71.8
# ..           ...          ...         ...    ...
# 115         4.95         7.63        75.0   72.5
# 116         4.45         4.97        84.8   70.7
# 117         2.75         7.19        82.1   62.9
# 118         6.21         6.34        88.2   97.4
# 119         5.63         7.85        76.7   84.3
#
# [120 rows x 4 columns]

# %%
df.head()
# Out:
#    study_hours  sleep_hours  attendance  marks
# 0         5.25         7.79        77.1   78.9
# 1         4.29         6.09        83.9   76.6
# 2         5.47         8.40        90.0   81.6
# 3         6.78         5.60        93.7   87.3
# 4         4.15         7.59        73.0   71.8

# %%
x=df[['study_hours','sleep_hours','attendance']]
y=df['marks']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(y_train.dtypes)
# Out:
# float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(x_test)
pred
# Out:
# array([58.49721656, 82.0011362 , 73.22497041, 64.18855392, 58.94702106,
#        76.85003588, 74.58348427, 67.97780426, 86.51570847, 84.46495165,
#        86.15604077, 52.65760414, 78.84086735, 83.58343699, 69.81559671,
#        68.11496038, 63.31048222, 74.96503636, 68.59181068, 62.38165507,
#        73.90143703, 65.47587649, 64.35955464, 62.33489204])

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
score=r2_score(y_test,pred)
score
# Out:
# 0.7715818924418367

# %%
sc=mean_squared_error(y_test,pred)
sc
# Out:
# 22.58597850975904

# %%
plt.scatter(df['study_hours'], df['marks'],c=df['sleep_hours'])
plt.colorbar(label='sleep hours')
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.show()
